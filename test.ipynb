# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from keras.models import load_model

# %%
n = 1055
X_img = pickle.load(open("X.pickle", 'rb'))
plt.imshow(X_img[n], cmap ="gray")

# %%
y = pickle.load(open("y.pickle", 'rb'))
print(int(y[n]))

# from tensorflow import keras

# (x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# X = x_test
# Out:
# 9

# %%
# img = cv2.imread('./2673.jpg', 0)
# img = cv2.resize(img, (28, 28), interpolation = cv2.INTER_CUBIC)
# X = img
num_classes = 10
input_shape = (28, 28, 1)
X = X_img.astype("float32") / 255
X = X.reshape(-1,28, 28, 1)

# y = keras.utils.to_categorical(y, num_classes)

model = load_model('./cnn_model_printed_digits.h5')
X.shape
# Out:
# (3015, 28, 28, 1)

# %%
res = model.predict(X)

# model.evaluate(X, y)

# %%
# # y.shape
# # print(y[1])
# # label = np.where(y[1] == 1.0)
# # label
# for i in range(10):
#     print( str(np.argmax(y[i])) + " -  " + str(np.argmax(res[i])) )

# %%
# n = 3000
np.argmax(res[0])
# Out:
# 8

# %%
plt.imshow(X[n], cmap ="gray")

# %%
import random 

plt.figure(figsize=(14,14))
for i in range(49):
    j = random.randint(0, 3015)
    plt.subplot(7, 7, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    plt.imshow(X_img[j], cmap=plt.cm.binary)
    plt.xlabel(str(round(max((res[n]) * 100), 2)) + "%- Pred: " + str(np.argmax(res[j])))
